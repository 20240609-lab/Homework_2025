# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/110del_d%5Bkey%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778}
del names['Mary']
print(names)
# Out:
# {'Cris': 2111, 'Aimy': 9778}

# %%
del names['Sams']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3085454307.py in <cell line: 0>()
# ----> 1 del names['Sams']
#
# KeyError: 'Sams'
