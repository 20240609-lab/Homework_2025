# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/151withopen()_as_f.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('myfile.txt','r')
readData = f.readlines()
f.close()

# %%
with open('myfile.txt','r') as f:
    readData = f.readlines()
