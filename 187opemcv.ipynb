# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/187opemcv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

def showImage(imgfile):
  img = cv2.imread(imgfile, cv2.IMREAD_COLOR)
  cv2.namedWindow('picture',cv2.WINDOW_AUTOSIZE)
  cv2.imshow('picture',img)
  cv2.waitKey(0)
  cv2.destroyAIIWindows()

showImage('sunrise.jpg')

# %%
import numpy as np
from random import shuffle

B = [i for i in range(256)]
G = [i for i in range(256)]
R = [i for i in range(256)]

# %%
def onMouse(eenvent,x,y,flags,param):
  if event == cv2.EVENT_LBUTTONDBLCLK:
    shuffle(B)
    shuffle(G)
    shuffle(R)
    cv2.circle(param,(x,y),50,(B[0],G[0],R[0]),-1)

# %%
def mouseBrush():
  img = np.zeros((576,1024,3),np.uint8)
  cv2.namedWindow('drawing pad')
  cv2.setMouseCallback('drawing pad',onMouse,img)

  while True:
    cv2.imshow('drawing pad',img)
    k = cv2.waitKey(1) & 0xFF
    if k == 27:
      break
  cv2.destroyAllWindows()

mouseBrush()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2612871232.py in <cell line: 0>()
#      11   cv2.destroyAllWindows()
#      12
# ---> 13 mouseBrush()
#
# /tmp/ipython-input-2612871232.py in mouseBrush()
#       1 def mouseBrush():
#       2   img = np.zeros((576,1024,3),np.uint8)
# ----> 3   cv2.namedWindow('drawing pad')
#       4   cv2.setMouseCallback('drawing pad',onMouse,img)
#       5
#
# NameError: name 'cv2' is not defined
