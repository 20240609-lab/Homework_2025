# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/162os_getcwd().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import getcwd

print(f'현재 작업 디렉토리:{getcwd()}')
# Out:
# 현재 작업 디렉토리:/content

# %%
from os import chdir
print(f'현재 작업 디렉토리:{getcwd()}')
chdir('..')
print(f'현재 작업 디렉토리:{getcwd()}')
chdir('c:/mywork/jupyter')
print(f'현재 작업 디렉토리:{getcwd()}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2697063837.py in <cell line: 0>()
#       1 from os import chdir
# ----> 2 print(f'현재 작업 디렉토리:{getcwd()}')
#       3 chdir('..')
#       4 print(f'현재 작업 디렉토리:{getcwd()}')
#       5 chdir('c:/mywork/jupyter')
#
# NameError: name 'getcwd' is not defined
