# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/150f_open().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = open('myfile.txt','w',encoding='cp494')
f.close()

f = open('image.jpg','rb')
f.close()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipython-input-1901233665.py in <cell line: 0>()
# ----> 1 f = open('myfile.txt','w',encoding='cp494')
#       2 f.close()
#       3
#       4 f = open('image.jpg','rb')
#       5 f.close()
#
# LookupError: unknown encoding: cp494
