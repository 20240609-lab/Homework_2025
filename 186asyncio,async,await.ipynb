# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/186asyncio%2Casync%2Cawait.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import asyncio
from time import time

async def sayAfter(delay,saying):
  print(f'sayAfter({delay},ssaying)시작...')
  await asyncio.sleep(delay)
  print(saying)

# %%
async def main():
  print('비동기 함수 main() 시작...')
  stime = time()
  await sayAfter(1,'안녕하세요!')
  await sayAfter(2,'방가방가~~')
  etime = time()
  print(f'총 소요 시간:{etime-stime:.2f}초')

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1024711636.py in <cell line: 0>()
#       7   print(f'총 소요 시간:{etime-stime:.2f}초')
#       8
# ----> 9 asyncio.run(main())
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     189     if events._get_running_loop() is not None:
#     190         # fail fast with short traceback
# --> 191         raise RuntimeError(
#     192             "asyncio.run() cannot be called from a running event loop")
#     193
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
async def main():
  print('비동기 함수 main() 시작...')
  tasks = []
  tasks.append(asyncio.create_task(sayAfter(1,'안녕하세요!')))
  tasks.append(asyncio.create_task(sayAfter(2,'방가방가~~')))

  stime = time()
  await asyncio.wait(tasks)
  etime = time()
  print(f'총 소요 시간:{etime-stime:.2f}초')

await main()
# Out:
# 비동기 함수 main() 시작...
# sayAfter(1,ssaying)시작...
# sayAfter(2,ssaying)시작...
# 안녕하세요!
# 방가방가~~
# 총 소요 시간:2.00초

# %%
from time import sleep

async def sayAfter(delay,saying):
  print(f'sayAfter({delay},saying)시작...')
  sleep(delay)
  print((saying))
