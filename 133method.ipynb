# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/133method.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
  generated = 0

  def setFireballLevel(self,power=1):
    self.fireballLevel = power
    print(f'화염구 강도를 {power}로 설정합니다.')

  @classmethod
  def addGenerated(cls, count):
    cls.generated += count
    print(f'생성된 총 캐릭터 수 : {cls.generated}')

  @staticmethod
  def static1():
    print('Wizard 클래스에서 정의된 정적 메서드입니다.')

# %%
player1 = Wizard()
player1.setFireballLevel(8)
Wizard.addGenerated(2)
Wizard.static1()
# Out:
# 화염구 강도를 8로 설정합니다.
# 생성된 총 캐릭터 수 : 2
# Wizard 클래스에서 정의된 정적 메서드입니다.
