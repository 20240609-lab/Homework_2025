# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/155_readline().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('prophet_en.txt','r')as f:
  line = f.readline()
  while line != '':
    print(f'>>{line[:-1]}')
    k = input('다음 줄: 엔터 입력. 종료: /q 입력: ')
    if k == '/q':
      break
    line = f.readline()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2217255396.py in <cell line: 0>()
# ----> 1 with open('prophet_en.txt','r')as f:
#       2   line = f.readline()
#       3   while line != '':
#       4     print(f'>>{line[:-1]}')
#       5     k = input('다음 줄: 엔터 입력. 종료: /q 입력: ')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'

# %%
with open('prophet_en.txt','r')as f:
  lines = f.readlines()
  for line in lines:
    print(f'>>{line[:-1]}')
    k = input('다음줄: 엔터 입력. 종료: /q 입력: ')
    if k == '/q':
      break
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4274455757.py in <cell line: 0>()
# ----> 1 with open('prophet_en.txt','r')as f:
#       2   lines = f.readlines()
#       3   for line in lines:
#       4     print(f'>>{line[:-1]}')
#       5     k = input('다음줄: 엔터 입력. 종료: /q 입력: ')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'
