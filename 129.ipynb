# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def setLevel(character: str, level: int) -> dict[str, int]:
  return {character:level}

# %%
def setLevel(character:str, level:int) -> None:
  global greats
  greats[character] = level
  return

# %%
greats = {'유비':10,'관우':15,'장비':10}
setLevel('유비',13)
print(greats)
# Out:
# {'유비': 13, '관우': 15, '장비': 10}
