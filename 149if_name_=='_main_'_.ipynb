# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/149if_name_%3D%3D'_main_'_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def printName():
  print(f'module_b의 _name_={__name__}')

# %%
def printName():
  print(f'module_b의 _name_={__name__}')

printName()
print(f'실행 모듈인 이 모듈의 _name_ = {__name__}')
# Out:
# module_b의 _name_=__main__
# 실행 모듈인 이 모듈의 _name_ = __main__

# %%
def printName():
  print(f'module_b의 _name_={__name__}')

if __name__=='_main_':
  print('이 모듈은 처음 실행되는 코드입니다.')
  printName()
