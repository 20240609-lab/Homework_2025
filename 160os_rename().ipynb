# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/160os_rename().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import rename

src = 'sunrise_copied.jpg'
dst = 'sunrise2.jpg'
rename(src,dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2580926482.py in <cell line: 0>()
#       3 src = 'sunrise_copied.jpg'
#       4 dst = 'sunrise2.jpg'
# ----> 5 rename(src,dst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise_copied.jpg' -> 'sunrise2.jpg'

# %%
src = 'sunrise2.jpg'
dst = 'tmp/sunrise2.jpg'
rename(src,dst)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1848308994.py in <cell line: 0>()
#       1 src = 'sunrise2.jpg'
#       2 dst = 'tmp/sunrise2.jpg'
# ----> 3 rename(src,dst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise2.jpg' -> 'tmp/sunrise2.jpg'
