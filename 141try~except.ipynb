# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/141try~except.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intList = range(10)
try:
  idx = int(input('숫자를 입력하세요: '))
  print(intList[idx])
except ValueError:
  print('입력한 내용이 숫자가 아닙니다!')
except IndexError as e:
  print(f'인덱스 오류가 발생:{e}')
# Out:
# 숫자를 입력하세요: a
# 입력한 내용이 숫자가 아닙니다!
