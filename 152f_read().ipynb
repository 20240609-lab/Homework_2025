# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/152f_read().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('prophet_en.txt','r')as f:
  readData = f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3518807833.py in <cell line: 0>()
# ----> 1 with open('prophet_en.txt','r')as f:
#       2   readData = f.read()
#       3 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'

# %%
with open('prophet_ko.txt','r')as f:
  readData = f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-672519753.py in <cell line: 0>()
# ----> 1 with open('prophet_ko.txt','r')as f:
#       2   readData = f.read()
#       3 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_ko.txt'

# %%
with open('prophet_cp949_ko.txt','r',encoding='cp949')as f:
  readData = f.read()
print(readData)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1321730846.py in <cell line: 0>()
# ----> 1 with open('prophet_cp949_ko.txt','r',encoding='cp949')as f:
#       2   readData = f.read()
#       3 print(readData)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_cp949_ko.txt'

# %%
with open('sunrise.jpg','rb')as f:
  readData = f.read(50)
print(readData.hex('-'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-535546039.py in <cell line: 0>()
# ----> 1 with open('sunrise.jpg','rb')as f:
#       2   readData = f.read(50)
#       3 print(readData.hex('-'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise.jpg'
