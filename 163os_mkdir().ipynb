# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/163os_mkdir().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import mkdir

folder = 'myfolder'
mkdir(folder)

# %%
folder = 'c:/mywork/jupyter/myfolder2'
mkdir(folder)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-995760255.py in <cell line: 0>()
#       1 folder = 'c:/mywork/jupyter/myfolder2'
# ----> 2 mkdir(folder)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/mywork/jupyter/myfolder2'

# %%
from os import rmdir

folder = 'myfolder'
forlder2 = 'c:/mywork/jupyter/myfolder2'
rmdir(folder)
rmdir(forlder2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-922364025.py in <cell line: 0>()
#       4 forlder2 = 'c:/mywork/jupyter/myfolder2'
#       5 rmdir(folder)
# ----> 6 rmdir(forlder2)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/mywork/jupyter/myfolder2'
