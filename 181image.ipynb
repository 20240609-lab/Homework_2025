# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/181image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def my_urlopen(url):
  header={"User-Agent":"Mozilla/5.0 (Windows NT 10.0;Win64;x64) AppleWebKit/537.36(KHTML,like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
  try:
    with requests.get(url,headers=header)as r:
      return r
  except Exception as e:
    print(f'my_urlopen()오류: url={url}\n{e}')
    return None

# %%
def getImgSize(headers):
  try:
    imgsize = int(headers['content-length'])
    return imgsize
  except Exception as e:
    print(f'getImgSize() 오류:{e}')
    return -1

# %%
def saveImage(url,filename):
  r = my_urlopen(url)
  if r != None:
    imgdata = r.content
    imgsize = getImgSize(r.headers)
    if imgsize == -1:
      print(f'{url}:이미지 사이즈를 알 수 없습니다.')
      return

    with open(filename,'wb')as h:
      h.write(imgdata)
    print(f'이미지 크기:{imgsize:,}바이트 다운로드 완료')

# %%
url = 'http://www.anydle.com:8283/python200-new/sunrise_full.jpg'
saveImage(url,'sunrise_full.jpg')
# Out:
# 이미지 크기:281바이트 다운로드 완료
