# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/176socket2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

HOST = 'localhost'
PORT = 7777

def echoclient():
  with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
    try:
      sock.bind((HOST, PORT))
      print(f'[{HOST}]와 연결되었습니다.')
      msg = input('메시지 입력: ')
      sock.sendall(msg.encode())
      print(f'에코 서버로 전송한 데이터: {msg}')
      data = sock.recv(1024)
      print(f'에코 서버로 부터 수신한 데이터: {data.decode()}')
    except Exception as e:
      print(e)

echoclient()
# Out:
# [localhost]와 연결되었습니다.
# 메시지 입력: 사랑해요 파이썬!!
# [Errno 32] Broken pipe
