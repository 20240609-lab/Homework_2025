# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/178socket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

HOST = 'localhost'
PORT = 7777

def echoclient2():
  with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
    sock.connect((HOST,PORT))

    while True:
      msg = input('메시지 입력: ')
      if msg == '/q':
        sock.sendall(msg.encode())
        break

      sock.sendall(msg.encode())
      data = sock.recv(1024)
      print(f'에코 서버로부터 받은 메시지 [{data.decode()}]')

    print('클라이언트 종료')

echoclient2()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /tmp/ipython-input-1204533511.py in <cell line: 0>()
#      20     print('클라이언트 종료')
#      21
# ---> 22 echoclient2()
#
# /tmp/ipython-input-1204533511.py in echoclient2()
#       6 def echoclient2():
#       7   with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as sock:
# ----> 8     sock.connect((HOST,PORT))
#       9
#      10     while True:
#
# ConnectionRefusedError: [Errno 111] Connection refused
