# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/171time_localtime().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import localtime,strftime

t = localtime()
today = strftime('%Y-%m-%d',t)
print(f'{today}은{t.tm_year}-01-01 이후{t.tm_yday}일째 되는 날입니다.')
# Out:
# 2025-12-09은2025-01-01 이후343일째 되는 날입니다.
