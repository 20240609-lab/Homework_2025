# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/130decorator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def report():
  print('이 부분은 리포트의 본문입니다.')

# %%
def makeNumber():
  for i in range(3):
    print(i)

# %%
report()
# Out:
# 이 부분은 리포트의 본문입니다.

# %%
makeNumber()
# Out:
# 0
# 1
# 2

# %%
def report1():
  print('-'*50)
  print('이 부분은 리포트의 본문입니다.')
  print('-'*50)
  return

def makeNumber1():
  print('-'*50)
  for i in range(3):
    print(i)
  print('-'*50)
  return

# %%
def makeForm(func):
  def drawLine():
    print('-'*50)
    func()
    print('-'*50)
  return drawLine

# %%
report_new = makeForm(report)
report_new()
# Out:
# --------------------------------------------------
# 이 부분은 리포트의 본문입니다.
# --------------------------------------------------
