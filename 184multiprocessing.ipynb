# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/184multiprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from multiprocessing import Process
from time import time

x = 2305843009213693951
n = 1234567890

p1 = Process(target=checkPrimeNumber,args=(x,))
p2 = Process(target=cumulativeSum,args=(n,))
stime = time()
p1.start()
p2.start()
p1.join()
p2.join()
etime = time()
print(f'+++총 소요 시간 {etime-stime:.2f}초')
# Out:
# 2,305,843,009,213,693,951가 소수인지 아닌지 판별 중...
# 2,305,843,009,213,693,951는 소수입니다. 소요시간:0.00초1,234,567,890까지 누적합 계산중...
