# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/158os_path_getsize().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import getsize

file1 = 'sunrise.jpg'
file2 = 'C:/data/temp/DJI_0128.MP4'
file3 = '../../temp/DJI_0129,MP4'

# %%
print(f'{file1}: {get_ipython(file1):,}바이트')
print(f'{file2}: {get_ipython(file2):,}바이트')
print(f'{file3}: {get_ipython(file3):,}바이트')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2323026527.py in <cell line: 0>()
# ----> 1 print(f'{file1}: {get_ipython(file1):,}바이트')
#       2 print(f'{file2}: {get_ipython(file2):,}바이트')
#       3 print(f'{file3}: {get_ipython(file3):,}바이트')
#
# TypeError: InteractiveShell.get_ipython() takes 1 positional argument but 2 were given
