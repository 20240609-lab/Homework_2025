# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/112key_not_in_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
frequency = {}
while True:
  c = input('알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:')
  if c == '':
    break
  if c not in frequency:
    frequency[c] = 1
  else:
    frequency[c] += 1
  print(frequency)
# Out:
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:A
# {'A': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:B
# {'A': 1, 'B': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:C
# {'A': 1, 'B': 1, 'C': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:A
# {'A': 2, 'B': 1, 'C': 1}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:C
# {'A': 2, 'B': 1, 'C': 2}
# 알파벳 1자를 입력하세요[끝내려면 엔터를 치세요]:
