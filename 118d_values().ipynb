# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/118d_values().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
levels = greats.values()
print(list(levels))
# Out:
# [89, 95, 91, 94]

# %%
greats['조운']=97
print(list(levels))
# Out:
# [89, 95, 91, 97]
