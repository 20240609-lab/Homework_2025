# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/119reversed(d).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
greats = {'유비':89,'관우':95,'장비':91,'조운':94}
levels = reversed(greats)
print(list(levels))
# Out:
# ['조운', '장비', '관우', '유비']
