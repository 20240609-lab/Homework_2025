# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/165os_path_exists().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import exists

print(exists('sunrise.jpg'))
print(exists('tmp'))
print(exists('c:/mywork/jupyter/bts.mp4'))
# Out:
# False
# False
# False

# %%
from os import mkdir
from os.path import exists

while True:
  folder = input('생성할 디렉토리 이름을 입력하세요:')
  if exists(folder):
    print(f'<{folder}>가 이미 존재합니다.')
    continue
  else:
    mkdir(folder)
    print(f'<{folder}>를 생성했습니다.')
    break
# Out:
# 생성할 디렉토리 이름을 입력하세요:tmp
# <tmp>가 이미 존재합니다.
# 생성할 디렉토리 이름을 입력하세요:tmp2
# <tmp2>를 생성했습니다.
