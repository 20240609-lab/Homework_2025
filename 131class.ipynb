# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/131class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Wizard:
  num_of_generatred = 0
  def setName(self,name):
    self.name = name

# %%
player1 = Wizard()
player1.setName('FirePlayer')
print(player1.name)
# Out:
# FirePlayer
