# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/154f_seek().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('prophet_en.txt','r')as f:
  f.seek(335)
  data = f.read()
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1339976920.py in <cell line: 0>()
# ----> 1 with open('prophet_en.txt','r')as f:
#       2   f.seek(335)
#       3   data = f.read()
#       4 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prophet_en.txt'
