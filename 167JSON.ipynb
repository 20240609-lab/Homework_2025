# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/167JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

with open('package.json')as f:
  data = json.load(f)
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2669213215.py in <cell line: 0>()
#       1 import json
#       2
# ----> 3 with open('package.json')as f:
#       4   data = json.load(f)
#       5 print(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'package.json'

# %%
profile = {'name':'조조','age':45,'nationality':'위나라','skill':['집착','배신'],'alibe':True}
with open('profile.json','w')as f:
  json.dump(profile,f,indent=4)

# %%
with open('profile.json')as f:
  data = json.load(f)
print(data)
# Out:
# {'name': '조조', 'age': 45, 'nationality': '위나라', 'skill': ['집착', '배신'], 'alibe': True}

# %%
with open('profile.json','w')as f:
  json.dump(profile,f,indent=4,ensure_ascii=False)
