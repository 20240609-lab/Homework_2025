# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/172time_localtime().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from time import localtime, strftime

weekdays = ['월요일','화요일','수요일','목요일','토요일','일요일']
t = localtime()
today = strftime('%Y-%m-%d',t)
print(f'{today}은 {weekdays[t.tm_wday]}입니다.')
# Out:
# 2025-12-09은 화요일입니다.
