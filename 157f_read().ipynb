# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/157f_read().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bufsize = 1024
with open('sunrise.jpg','rb')as f:
  with open('sunrise_copied.jpg','wb')as h:
    data = f.read(bufsize)
    while data:
      h.write(data)
      data = f.read(bufsize)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2731369264.py in <cell line: 0>()
#       1 bufsize = 1024
# ----> 2 with open('sunrise.jpg','rb')as f:
#       3   with open('sunrise_copied.jpg','wb')as h:
#       4     data = f.read(bufsize)
#       5     while data:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sunrise.jpg'
