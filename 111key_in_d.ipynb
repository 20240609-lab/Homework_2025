# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/111key_in_d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
name = input('이름을 입력하세요 :')
if name in names:
  print(f'이름이<{name}>인 출생아수는 <{names[name]:,d}>명입니다.')
else:
  print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
# Out:
# 이름을 입력하세요 :Cris
# 이름이<Cris>인 출생아수는 <2,111>명입니다.

# %%
names = {'Mary':10999,'Cris':2111,'Aimy':9778,'Tom':20245}
name = input('이름을 입력하세요 :')
if name in names:
  print(f'이름이<{name}>인 출생아수는 <{names[name]:,d}>명입니다.')
else:
  print(f'딕셔너리 names에 <{name}>인 이름이 존재하지 않습니다.')
# Out:
# 이름을 입력하세요 :Smas
# 딕셔너리 names에 <Smas>인 이름이 존재하지 않습니다.
