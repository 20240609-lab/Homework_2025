# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/126global().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
param = 10
def func1(param):
  localData = 5
  print(f'param={param}')
  return

func1(5)
print(f'param={param}')
# Out:
# param=5
# param=10

# %%
param = 10
def func2():
  param = 20
  return param

ret = func2()
print(f'param={param}')
# Out:
# param=10

# %%
param = 10
def func3():
  global param
  param = 20
  return

func3()
print(f'param={param}')
# Out:
# param=20
