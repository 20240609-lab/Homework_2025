# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/166os_path_isfile().ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from os.path import isdir

fileList = []
dirList = []
files = listdir('./')
for file in files:
  if isdir(file):
    dirList.append(file)
  else:
    fileList.append(file)

fileList.sort()
dirList.sort()

for d in dirList:
  print(d)

for f in fileList:
  print(f)
# Out:
# .config
# sample_data
# tmp
# tmp2
