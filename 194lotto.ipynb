# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/194lotto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fastapi

# %%
# !pip install uvicorn

# %%
from fastapi import FastAPI
import uvicorn

app = FastAPI()

@app.get("/test")
async def test():
    return {'messages':'안녕하세요~! FastAPI!'}

if __name__ == "__main__":
    uvicorn.run(app="test:app", host="0.0.0.0", port=8001, reload=True)

# %%
from fastapi import FastAPI, Request
from fastapi.responses import HTMLResponse
from fastapi.templating import Jinja2Templates
from fastapi.staticfiles import StaticFiles
import uvicorn
from random import shuffle

async def getLottoNumber():
    balls = [i for i in range(1, 46)]
    ballimgs = {} # 로또볼 이미지를 저장하는 딕셔너리
    for i in balls:
        ballimg = f'/static/lottoball/{i}.png'
        ballimgs[i] = ballimg

    imgsrc = [] # 추출한 로또 번호에 대응되는 로또볼 img src 태그
    n = 0
    while n < 5:
        shuffle(balls)
        winning = balls[:6]
        winning.sort()
        for i in winning:
            imgsrc.append(ballimgs[i])

        imgsrc.append('<br>')
        n += 1

    return imgsrc

app = FastAPI()
app.mount("/static", StaticFiles(directory="static"), name="static")
templates = Jinja2Templates(directory='templates')

@app.get("/lotto", response_class=HTMLResponse)
async def getLotto(request: Request):
    imgsrc = await getLottoNumber()
    return templates.TemplateResponse('lotto.html', {'request': request, 'imgsrc':imgsrc})

if __name__ == "__main__":
    uvicorn.run(app="main:app", host="0.0.0.0", port=8001, reload=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1560555352.py in <cell line: 0>()
#      28
#      29 app = FastAPI()
# ---> 30 app.mount("/static", StaticFiles(directory="static"), name="static")
#      31 templates = Jinja2Templates(directory='templates')
#      32
#
# /usr/local/lib/python3.12/dist-packages/starlette/staticfiles.py in __init__(self, directory, packages, html, check_dir, follow_symlink)
#      54         self.follow_symlink = follow_symlink
#      55         if check_dir and directory is not None and not os.path.isdir(directory):
# ---> 56             raise RuntimeError(f"Directory '{directory}' does not exist")
#      57
#      58     def get_directories(
#
# RuntimeError: Directory 'static' does not exist
