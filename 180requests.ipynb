# %% [markdown]
# <a href="https://colab.research.google.com/github/20240609-lab/Homework_2025/blob/main/180requests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

def my_urlopen(url):
  header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36"}
  try:
    with requests.get(url,headers=header)as r:
      return r
    except Exception as e:
      print(f'my_urlopen() 오류: url={url}\n{e}')
      return None
# Out:
#   File "/tmp/ipython-input-3684878771.py", line 8
#     except Exception as e:
#     ^
# SyntaxError: invalid syntax

# %%
url = 'https://www.python.org/'
r = my_urlopen(url)
if r != None:
  doc = r.content.decode()
  with open('pythonhome2.html','w')as h:
    h.write(doc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1645645973.py in <cell line: 0>()
#       1 url = 'https://www.python.org/'
# ----> 2 r = my_urlopen(url)
#       3 if r != None:
#       4   doc = r.content.decode()
#       5   with open('pythonhome2.html','w')as h:
#
# NameError: name 'my_urlopen' is not defined
